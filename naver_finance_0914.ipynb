# %% [markdown]
# <a href="https://colab.research.google.com/github/jieunlee-hi/Portfolio/blob/main/naver_finance_0914.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
auth.authenticate_user()
from google.colab import drive
drive.mount('./drive')
# Out:
# Drive already mounted at ./drive; to attempt to forcibly remount, call drive.mount("./drive", force_remount=True).

# %% [markdown]
# ## 라이브러리 로드

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
def get_font_family():
    """
    시스템 환경에 따른 기본 폰트명을 반환하는 함수
    """
    import platform
    system_name = platform.system()
    # colab 사용자는 system_name이 'Linux'로 확인

    if system_name == "Darwin" :
        font_family = "AppleGothic"
    elif system_name == "Windows":
        font_family = "Malgun Gothic"
    else:
        # Linux
        # colab에서는 runtime을 <꼭> 재시작 해야합니다.
        # 런타임을 재시작 하지 않고 폰트 설치를 하면 기본 설정 폰트가 로드되어 한글이 깨집니다.
        # !apt-get update -qq
        # !apt-get install fonts-nanum -qq  > /dev/null

        import matplotlib.font_manager as fm

        fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
        font = fm.FontProperties(fname=fontpath, size=9)
        fm._rebuild()
        font_family = "NanumBarunGothic"
    return font_family

# %%
font_family = get_font_family()

# %%
# 그래프 스타일 설정
plt.style.use("seaborn")

# 폰트설정
plt.rc("font", family=font_family)

# 마이너스폰트 설정
plt.rc("axes", unicode_minus=False)

# 그래프에 retina display 적용
from IPython.display import set_matplotlib_formats
set_matplotlib_formats("retina")

# %%
# 한글폰트가 제대로 동작하는지 확인하기
pd.Series([1, 3, 5, -7, 9]).plot(title="한글")

# %%
#네이버금융 업종별 (ROE/PER/PBR) 데이터를 활용한 저평가종목 분석(2022.03 분기 기준)
#PER 작은값 /PBR 작은값/ROE 높은값 일수록 저평가된종목일 확률이 높다.
#66개종목 AVG=동일업종PER평균


df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/naver_finance.csv',encoding='cp949')

# %%
# head와 tail로 데이터의 일부를 가져와서 봅니다.
df.head(20)
# Out:
#         업종명  소속종목수       소속종목명      ROE     PER    PBR   DVR  PER_AVG  \
# 0   우주항공과국방     16        에이트원   -25.82     NaN   2.28   NaN    39.77
# 1   우주항공과국방     16  한화에어로스페이스      5.45   25.70   1.36  0.89    39.77
# 2   우주항공과국방     16        휴니드      1.26   74.91   0.86   NaN    39.77
# 3   우주항공과국방     16      한화시스템      0.86  161.22   1.36  1.01    39.77
# 4   우주항공과국방     16         아스트   -16.93     NaN   1.12   NaN    39.77
# 5   우주항공과국방     16        퍼스텍     -0.96     NaN   4.91   NaN    39.77
# 6   우주항공과국방     16  켄코아에어로스페이스   -65.30     NaN   7.75   NaN    39.77
# 7   우주항공과국방     16     아이쓰리시스템     6.94   28.42   1.87  0.50    39.77
# 8   우주항공과국방     16     LIG넥스원     18.86   15.62   2.62  1.14    39.77
# 9   우주항공과국방     16     한국항공우주      6.57   68.28   4.33  0.34    39.77
# 10  우주항공과국방     16          빅텍     4.74   65.15   2.96  0.47    39.77
# 11  우주항공과국방     16       쎄트렉아이     7.17   37.17   2.54  0.39    39.77
# 12  우주항공과국방     16       하이즈항공   -26.43     NaN   1.19   NaN    39.77
# 13  우주항공과국방     16         휴센텍  -105.92     NaN   5.72   NaN    39.77
# 14  우주항공과국방     16  어스앤에어로스페이스     1.45  191.23  10.04   NaN    39.77
# 15  우주항공과국방     16         제노코    20.76   30.25   5.74  0.19    39.77
# 16       건설     73      한미글로벌     11.75   12.70   1.22  2.51     7.03
# 17       건설     73          유신    16.30    7.17   1.09  2.15     7.03
# 18       건설     73       한신공영      6.97    3.38   0.23  2.63     7.03
# 19       건설     73     한국종합기술      8.05    8.47   0.63  1.14     7.03
#
#                                                   url
# 0   https://finance.naver.com/item/main.naver?code...
# 1   https://finance.naver.com/item/main.naver?code...
# 2   https://finance.naver.com/item/main.naver?code...
# 3   https://finance.naver.com/item/main.naver?code...
# 4   https://finance.naver.com/item/main.naver?code...
# 5   https://finance.naver.com/item/main.naver?code...
# 6   https://finance.naver.com/item/main.naver?code...
# 7   https://finance.naver.com/item/main.naver?code...
# 8   https://finance.naver.com/item/main.naver?code...
# 9   https://finance.naver.com/item/main.naver?code...
# 10  https://finance.naver.com/item/main.naver?code...
# 11  https://finance.naver.com/item/main.naver?code...
# 12  https://finance.naver.com/item/main.naver?code...
# 13  https://finance.naver.com/item/main.naver?code...
# 14  https://finance.naver.com/item/main.naver?code...
# 15  https://finance.naver.com/item/main.naver?code...
# 16  https://finance.naver.com/item/main.naver?code...
# 17  https://finance.naver.com/item/main.naver?code...
# 18  https://finance.naver.com/item/main.naver?code...
# 19  https://finance.naver.com/item/main.naver?code...

# %%
df.tail()
# Out:
#           업종명  소속종목수     소속종목명     ROE    PER   PBR   DVR  PER_AVG  \
# 2517     기타금융      8    메이슨캐피탈   -3.72    NaN  1.26   NaN     9.61
# 2518  디스플레이패널      4       비덴트   22.98   3.20  0.67   NaN     5.83
# 2519  디스플레이패널      4        코텍    1.05  45.88  0.44   NaN     5.83
# 2520  디스플레이패널      4  LG디스플레이     1.67  25.51  0.42  4.33     5.83
# 2521  디스플레이패널      4    일진디스플   -77.09    NaN  2.76   NaN     5.83
#
#                                                     url
# 2517  https://finance.naver.com/item/main.naver?code...
# 2518  https://finance.naver.com/item/main.naver?code...
# 2519  https://finance.naver.com/item/main.naver?code...
# 2520  https://finance.naver.com/item/main.naver?code...
# 2521  https://finance.naver.com/item/main.naver?code...

# %% [markdown]
# ## 중복데이터 제거하기
# * drop_duplicates 를 통해 중복된 데이터가 있다면 제거합니다.

# %%
# drop_duplicates : row들 끼리 data를 비교하여 같은 값이 있으면 row중 하나를 삭제
# df.shape를 전/후로 출력하여 삭제된 row가 있는지 확인
df = df.drop_duplicates()
df.shape
# Out:
# (2522, 9)

# %%
#EDA
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2522 entries, 0 to 2521
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   업종명      2522 non-null   object
#  1   소속종목수    2522 non-null   int64
#  2   소속종목명    2522 non-null   object
#  3   ROE      2297 non-null   object
#  4   PER      1726 non-null   object
#  5   PBR      2472 non-null   float64
#  6   DVR      1262 non-null   float64
#  7   PER_AVG  2495 non-null   float64
#  8   url      2522 non-null   object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 197.0+ KB

# %%
#결측값 여부 확인
df.isnull()
#네이버금융사이트 내에 데이터값이 없는 경우 결측값 발생
df.isnull().sum()
# Out:
# 업종명           0
# 소속종목수         0
# 소속종목명         0
# ROE         226
# PER         809
# PBR          50
# DVR        1260
# PER_AVG      27
# url           0
# dtype: int64

# %% [markdown]
# object 형 float64형으로 변환

# %%
df['ROE'] = pd.to_numeric(df['ROE'],errors='coerce')
df['PER'] = pd.to_numeric(df['PER'],errors='coerce')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2522 entries, 0 to 2521
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   업종명      2522 non-null   object
#  1   소속종목수    2522 non-null   int64
#  2   소속종목명    2522 non-null   object
#  3   ROE      2296 non-null   float64
#  4   PER      1713 non-null   float64
#  5   PBR      2472 non-null   float64
#  6   DVR      1262 non-null   float64
#  7   PER_AVG  2495 non-null   float64
#  8   url      2522 non-null   object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 197.0+ KB

# %% [markdown]
# ## 기술통계값 구하기

# %%
# describe는 기본적으로 수치데이터에 대한 기술통계값을 구하게 됩니다.
df.describe()
# Out:
#              소속종목수          ROE          PER          PBR          DVR  \
# count  2522.000000  2296.000000  1713.000000  2472.000000  1262.000000
# mean     71.065821     1.586921    33.981168     1.987071     2.311300
# std      44.748258    40.274727    80.806042     2.770782     1.958362
# min       1.000000  -776.290000     0.810000     0.070000     0.040000
# 25%      31.000000    -2.112500     6.820000     0.690000     0.940000
# 50%      69.000000     5.465000    13.020000     1.215000     1.710000
# 75%      94.000000    12.710000    26.920000     2.230000     3.200000
# max     160.000000   784.450000   951.670000    45.380000    16.180000
#
#            PER_AVG
# count  2495.000000
# mean     25.360389
# std      30.648949
# min       1.650000
# 25%       8.130000
# 50%      15.270000
# 75%      27.820000
# max     302.420000

# %% [markdown]
# # 대표 업종 : 제약

# %%
df_pharmaceutical=df[df['업종명']=='제약'].reset_index(drop=True)

# %%
df_pharmaceutical
# Out:
#     업종명  소속종목수        소속종목명     ROE    PER    PBR   DVR  PER_AVG  \
# 0    제약    160  프레스티지바이오로직스  -49.66    NaN   2.62   NaN    105.2
# 1    제약    160  프레스티지바이오파마   -19.99    NaN   1.40   NaN    105.2
# 2    제약    160       지놈앤컴퍼니  -36.54    NaN   3.32   NaN    105.2
# 3    제약    160        삼성제약   -22.79    NaN   2.08   NaN    105.2
# 4    제약    160        삼진제약     9.41  16.25   1.31  3.23    105.2
# ..   ..    ...          ...     ...    ...    ...   ...      ...
# 155  제약    160       일동홀딩스  -115.00    NaN   4.86  0.35    105.2
# 156  제약    160     에스씨엠생명과학  -43.40    NaN   3.34   NaN    105.2
# 157  제약    160         에이비온   25.04    NaN   6.24   NaN    105.2
# 158  제약    160      에이프릴바이오     NaN    NaN   3.03   NaN    105.2
# 159  제약    160        박셀바이오  -18.05    NaN  38.69   NaN    105.2
#
#                                                    url
# 0    https://finance.naver.com/item/main.naver?code...
# 1    https://finance.naver.com/item/main.naver?code...
# 2    https://finance.naver.com/item/main.naver?code...
# 3    https://finance.naver.com/item/main.naver?code...
# 4    https://finance.naver.com/item/main.naver?code...
# ..                                                 ...
# 155  https://finance.naver.com/item/main.naver?code...
# 156  https://finance.naver.com/item/main.naver?code...
# 157  https://finance.naver.com/item/main.naver?code...
# 158  https://finance.naver.com/item/main.naver?code...
# 159  https://finance.naver.com/item/main.naver?code...
#
# [160 rows x 9 columns]

# %% [markdown]
# ### PER, PBR,ROE 시각화

# %%
#ROE결측데이터삭제
ROE_pharmaceutical=df_pharmaceutical.dropna(subset=['ROE'])
ROE_pharmaceutical
# Out:
#     업종명  소속종목수        소속종목명     ROE    PER    PBR   DVR  PER_AVG  \
# 0    제약    160  프레스티지바이오로직스  -49.66    NaN   2.62   NaN    105.2
# 1    제약    160  프레스티지바이오파마   -19.99    NaN   1.40   NaN    105.2
# 2    제약    160       지놈앤컴퍼니  -36.54    NaN   3.32   NaN    105.2
# 3    제약    160        삼성제약   -22.79    NaN   2.08   NaN    105.2
# 4    제약    160        삼진제약     9.41  16.25   1.31  3.23    105.2
# ..   ..    ...          ...     ...    ...    ...   ...      ...
# 154  제약    160         아이큐어  -41.81    NaN   2.30   NaN    105.2
# 155  제약    160       일동홀딩스  -115.00    NaN   4.86  0.35    105.2
# 156  제약    160     에스씨엠생명과학  -43.40    NaN   3.34   NaN    105.2
# 157  제약    160         에이비온   25.04    NaN   6.24   NaN    105.2
# 159  제약    160        박셀바이오  -18.05    NaN  38.69   NaN    105.2
#
#                                                    url
# 0    https://finance.naver.com/item/main.naver?code...
# 1    https://finance.naver.com/item/main.naver?code...
# 2    https://finance.naver.com/item/main.naver?code...
# 3    https://finance.naver.com/item/main.naver?code...
# 4    https://finance.naver.com/item/main.naver?code...
# ..                                                 ...
# 154  https://finance.naver.com/item/main.naver?code...
# 155  https://finance.naver.com/item/main.naver?code...
# 156  https://finance.naver.com/item/main.naver?code...
# 157  https://finance.naver.com/item/main.naver?code...
# 159  https://finance.naver.com/item/main.naver?code...
#
# [144 rows x 9 columns]

# %%
ROE_pharmaceutical=ROE_pharmaceutical[["소속종목명", "ROE"]].sort_values("ROE").reset_index(drop=True)
ROE_pharmaceutical
# Out:
#            소속종목명     ROE
# 0         카이노스메드 -176.43
# 1         일동홀딩스  -115.00
# 2          일동제약   -67.77
# 3    브릿지바이오테라퓨틱스  -60.85
# 4       비보존 헬스케어  -60.76
# ..           ...     ...
# 139      더블유에스아이   22.63
# 140         에이비온   25.04
# 141        일성신약    26.71
# 142         대한뉴팜   27.01
# 143      팜젠사이언스    55.94
#
# [144 rows x 2 columns]

# %%
#ROE 10%정도 이상을 많이 추천하는데, ROE 10%이상만되어도 우수한기업 20-30%일경우 굉장한성장  *
#ROE가높을수록 PBR도 높아진다
ROE_pharmaceutical.set_index("소속종목명").tail(30).plot.barh()

# %%
#PBR
PBR_pharmaceutical=df_pharmaceutical.dropna(subset=['PBR'])
PBR_pharmaceutical=PBR_pharmaceutical[["소속종목명", "PBR"]].sort_values("PBR").reset_index(drop=True)
PBR_pharmaceutical
# Out:
#           소속종목명    PBR
# 0        씨케이에이치   0.07
# 1     코스맥스비티아이    0.25
# 2         일성신약    0.27
# 3    에이프로젠 H&G;   0.41
# 4      제일파마홀딩스    0.47
# ..          ...    ...
# 154         HLB  11.42
# 155        보로노이  11.49
# 156     SK바이오팜   14.39
# 157      카이노스메드  15.69
# 158       박셀바이오  38.69
#
# [159 rows x 2 columns]

# %%
#PBR : 주가순자산비율 (주가/주당순자산(총자산-총부채/발행주식수))
#PBR<1 저평가   *
PBR_pharmaceutical.set_index("소속종목명").tail(30).plot.barh()

# %%
#PER
#PER은 현재주식가격을 주당순이익으로 나눈값
#PER 시장평균
#PER 주가수익비율  = 주가 /주당순이익
#PER은 같은산업군에서 비교해야함.   *
PER_pharmaceutical=df_pharmaceutical.dropna(subset=['PER'])
PER_pharmaceutical=PER_pharmaceutical[["소속종목명", "PER"]].sort_values("PER").reset_index(drop=True)
PER_pharmaceutical
# Out:
#          소속종목명     PER
# 0      팜젠사이언스     1.31
# 1        일성신약     2.03
# 2       씨케이에이치    4.71
# 3         대한약품    6.14
# 4         대한뉴팜    6.72
# ..         ...     ...
# 82        에스티팜  174.09
# 83       CMG제약  175.67
# 84       현대약품   176.90
# 85  JW중외제약2우B   186.58
# 86    한올바이오파마   891.67
#
# [87 rows x 2 columns]

# %%
#PER이 낮을수록 기업의 수익성이좋고, PBR이 낮을수록 기업의 재무건전성이 좋다고 생각된다.
#통상적으로 PER은 10보다 낮을 때, PBR은 1모다 낮을때 저평가되어있다고 말한다. 하지만 기업의 수익성이나 자산은 업종별로 천차만별이기 때문에
#업종평균 PER과 PBR로 고려해야한다.
PBR_pharmaceutical.set_index("소속종목명").tail(30).plot.barh()

# %% [markdown]
# ## 상관분석

# %%
df_pharmaceutical_corr=df_pharmaceutical[["소속종목명","ROE","PER","PBR"]]
df_pharmaceutical_corr
# Out:
#            소속종목명     ROE    PER    PBR
# 0    프레스티지바이오로직스  -49.66    NaN   2.62
# 1    프레스티지바이오파마   -19.99    NaN   1.40
# 2         지놈앤컴퍼니  -36.54    NaN   3.32
# 3          삼성제약   -22.79    NaN   2.08
# 4          삼진제약     9.41  16.25   1.31
# ..           ...     ...    ...    ...
# 155       일동홀딩스  -115.00    NaN   4.86
# 156     에스씨엠생명과학  -43.40    NaN   3.34
# 157         에이비온   25.04    NaN   6.24
# 158      에이프릴바이오     NaN    NaN   3.03
# 159        박셀바이오  -18.05    NaN  38.69
#
# [160 rows x 4 columns]

# %%
df_pharmaceutical_corr.corr()
# Out:
#           ROE       PER       PBR
# ROE  1.000000 -0.288404 -0.294217
# PER -0.288404  1.000000  0.393938
# PBR -0.294217  0.393938  1.000000

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data = df_pharmaceutical_corr.corr(), annot=True, fmt = '.2f', linewidths=.5, cmap='Blues')

# %% [markdown]
# ## 이상치 존재 유무 시각화

# %%
#이상치 존재 유무 시각화
plt.figure(figsize=(12,8))
sns.boxplot(data=df[['ROE','PER','PBR','DVR','PER_AVG']],color='red',notch=True)
plt.show()

# %%
#결측값 여부 확인
df.isnull()
#네이버금융사이트 내에 데이터값이 없는 경우 결측값 발생
df.isnull().sum()
# Out:
# 업종명           0
# 소속종목수         0
# 소속종목명         0
# ROE         226
# PER         809
# PBR          50
# DVR        1260
# PER_AVG      27
# url           0
# dtype: int64

# %%
#결측값이 들어있는 행 전체 삭제
df=df.dropna(axis=0)

# %%
#결측값 여부 확인
df.isnull()
#네이버금융사이트 내에 데이터값이 없는 경우 결측값 발생
df.isnull().sum()
# Out:
# 업종명      0
# 소속종목수    0
# 소속종목명    0
# ROE      0
# PER      0
# PBR      0
# AVG      0
# url      0
# dtype: int64

# %%
#결측치 삭제 후 이상치 존재 유무 시각화
plt.figure(figsize=(12,8))
sns.boxplot(data=df[['ROE','PER','PBR','AVG']],color='red',notch=True)
plt.show()

# %%
#이상치값 IQR 구하기
Q1=df.quantile(0.25)
Q3=df.quantile(0.75)
IQR=Q3-Q1
Q1 - 1.5 * IQR, Q3 + 1.5 * IQR
# Out:
# (소속종목수   -54.5000
#  ROE     -23.7725
#  PER     -34.8375
#  PBR      -1.4825
#  AVG     -17.9750
#  dtype: float64, 소속종목수    181.5000
#  ROE       34.7275
#  PER       49.6225
#  PBR        4.2175
#  AVG       52.5450
#  dtype: float64)

# %% [markdown]
# 이상치검출

# %%
# ROE_Q3 = df.quantile(0.75) # df['ROE'].quantile(0.75) 처럼 특정 열만 적용 가능
# ROE_Q1 = df.quantile(0.25)

# ROE_IQR = ROE_Q3 - ROE_Q1
# 'ROE' 열에 대하여 이상치 여부를 판별해주는 함수
def is_ROE_outlier(df):
  roe_score = df['ROE']
  if roe_score > Q3['ROE'] + 1.5 * IQR['ROE'] or roe_score < Q1['ROE'] - 1.5 * IQR['ROE']:
      return True
  else:
      return False


# apply 함수를 통하여 각 값의 이상치 여부를 찾고 새로운 열에 결과 저장
df['ROE_IQR'] = df.apply(is_ROE_outlier, axis = 1) # axis = 1 지정 필수
# Out:
#           업종명  소속종목수      소속종목명    ROE     PER   PBR    AVG  \
# 0     우주항공과국방     16  한화에어로스페이스   7.33   12.51  0.89  31.28
# 1     우주항공과국방     16     LIG넥스원  17.50   13.47  2.18  31.28
# 2     우주항공과국방     16     한국항공우주   7.14   56.01  3.85  31.28
# 3     우주항공과국방     16      한화시스템   5.38   26.73  1.15  31.28
# 4     우주항공과국방     16        제노코  20.25   28.00  5.28  31.28
# ...       ...    ...        ...    ...     ...   ...    ...
# 2427    석유와가스     20    SK이노베이션   9.01   11.34  0.82   7.11
# 2428    석유와가스     20     중앙에너비스   0.90  235.47  1.53   7.11
# 2429    석유와가스     20      세원이앤씨  -4.96  -14.56  0.75   7.11
# 2430    석유와가스     20      S-Oil  28.09    5.53  1.40   7.11
# 2431    석유와가스     20     S-Oil우  28.09    5.53  1.40   7.11
#
#                                                     url  ROE_IQR
# 0     https://finance.naver.com/item/main.naver?code...    False
# 1     https://finance.naver.com/item/main.naver?code...    False
# 2     https://finance.naver.com/item/main.naver?code...    False
# 3     https://finance.naver.com/item/main.naver?code...    False
# 4     https://finance.naver.com/item/main.naver?code...    False
# ...                                                 ...      ...
# 2427  https://finance.naver.com/item/main.naver?code...    False
# 2428  https://finance.naver.com/item/main.naver?code...    False
# 2429  https://finance.naver.com/item/main.naver?code...    False
# 2430  https://finance.naver.com/item/main.naver?code...    False
# 2431  https://finance.naver.com/item/main.naver?code...    False
#
# [2235 rows x 9 columns]

# %%
df.head(100)
# Out:
#          업종명  소속종목수      소속종목명    ROE    PER   PBR    AVG  \
# 0    우주항공과국방     16  한화에어로스페이스   7.33  12.51  0.89  31.28
# 1    우주항공과국방     16     LIG넥스원  17.50  13.47  2.18  31.28
# 2    우주항공과국방     16     한국항공우주   7.14  56.01  3.85  31.28
# 3    우주항공과국방     16      한화시스템   5.38  26.73  1.15  31.28
# 4    우주항공과국방     16        제노코  20.25  28.00  5.28  31.28
# ..       ...    ...        ...    ...    ...   ...    ...
# 100       기계     93       대동기어   6.07  16.74  0.99  17.37
# 101       기계     93    에스피시스템스  -3.94 -72.11  2.63  17.37
# 102       기계     93     테라사이언스  -5.67 -45.62  3.79  17.37
# 103       기계     93         스맥 -17.67  -6.06  1.08  17.37
# 104       기계     93       휴림로봇 -23.86 -23.13  6.16  17.37
#
#                                                    url  ROE_IQR
# 0    https://finance.naver.com/item/main.naver?code...    False
# 1    https://finance.naver.com/item/main.naver?code...    False
# 2    https://finance.naver.com/item/main.naver?code...    False
# 3    https://finance.naver.com/item/main.naver?code...    False
# 4    https://finance.naver.com/item/main.naver?code...    False
# ..                                                 ...      ...
# 100  https://finance.naver.com/item/main.naver?code...    False
# 101  https://finance.naver.com/item/main.naver?code...    False
# 102  https://finance.naver.com/item/main.naver?code...    False
# 103  https://finance.naver.com/item/main.naver?code...    False
# 104  https://finance.naver.com/item/main.naver?code...     True
#
# [100 rows x 9 columns]

# %%
# PER_Q3 = df.quantile(0.75) # df['ROE'].quantile(0.75) 처럼 특정 열만 적용 가능
# PER_Q1 = df.quantile(0.25)

# PER_IQR = PER_Q3 - PER_Q1

# 'PER' 열에 대하여 이상치 여부를 판별해주는 함수
def is_PER_outlier(df):
  per_score = df['PER']
  if per_score > Q3['PER'] + 1.5 * IQR['PER'] or per_score < Q1['PER'] - 1.5 * IQR['PER']:
      return True
  else:
      return False

df['PER_IQR'] = df.apply(is_PER_outlier, axis = 1) # axis = 1 지정 필수
df
# Out:
#           업종명  소속종목수      소속종목명    ROE     PER   PBR    AVG  \
# 0     우주항공과국방     16  한화에어로스페이스   7.33   12.51  0.89  31.28
# 1     우주항공과국방     16     LIG넥스원  17.50   13.47  2.18  31.28
# 2     우주항공과국방     16     한국항공우주   7.14   56.01  3.85  31.28
# 3     우주항공과국방     16      한화시스템   5.38   26.73  1.15  31.28
# 4     우주항공과국방     16        제노코  20.25   28.00  5.28  31.28
# ...       ...    ...        ...    ...     ...   ...    ...
# 2427    석유와가스     20    SK이노베이션   9.01   11.34  0.82   7.11
# 2428    석유와가스     20     중앙에너비스   0.90  235.47  1.53   7.11
# 2429    석유와가스     20      세원이앤씨  -4.96  -14.56  0.75   7.11
# 2430    석유와가스     20      S-Oil  28.09    5.53  1.40   7.11
# 2431    석유와가스     20     S-Oil우  28.09    5.53  1.40   7.11
#
#                                                     url  ROE_IQR  PER_IQR
# 0     https://finance.naver.com/item/main.naver?code...    False    False
# 1     https://finance.naver.com/item/main.naver?code...    False    False
# 2     https://finance.naver.com/item/main.naver?code...    False     True
# 3     https://finance.naver.com/item/main.naver?code...    False    False
# 4     https://finance.naver.com/item/main.naver?code...    False    False
# ...                                                 ...      ...      ...
# 2427  https://finance.naver.com/item/main.naver?code...    False    False
# 2428  https://finance.naver.com/item/main.naver?code...    False     True
# 2429  https://finance.naver.com/item/main.naver?code...    False    False
# 2430  https://finance.naver.com/item/main.naver?code...    False    False
# 2431  https://finance.naver.com/item/main.naver?code...    False    False
#
# [2235 rows x 10 columns]

# %%
# 'PBR' 열에 대하여 이상치 여부를 판별해주는 함수
def is_PBR_outlier(df):
  pbr_score = df['PBR']
  if pbr_score > Q3['PBR'] + 1.5 * IQR['PBR'] or pbr_score < Q1['PBR'] - 1.5 * IQR['PBR']:
      return True
  else:
      return False
df['PBR_IQR'] = df.apply(is_PBR_outlier, axis = 1) # axis = 1 지정 필수
df
# Out:
#           업종명  소속종목수      소속종목명    ROE     PER   PBR    AVG  \
# 0     우주항공과국방     16  한화에어로스페이스   7.33   12.51  0.89  31.28
# 1     우주항공과국방     16     LIG넥스원  17.50   13.47  2.18  31.28
# 2     우주항공과국방     16     한국항공우주   7.14   56.01  3.85  31.28
# 3     우주항공과국방     16      한화시스템   5.38   26.73  1.15  31.28
# 4     우주항공과국방     16        제노코  20.25   28.00  5.28  31.28
# ...       ...    ...        ...    ...     ...   ...    ...
# 2427    석유와가스     20    SK이노베이션   9.01   11.34  0.82   7.11
# 2428    석유와가스     20     중앙에너비스   0.90  235.47  1.53   7.11
# 2429    석유와가스     20      세원이앤씨  -4.96  -14.56  0.75   7.11
# 2430    석유와가스     20      S-Oil  28.09    5.53  1.40   7.11
# 2431    석유와가스     20     S-Oil우  28.09    5.53  1.40   7.11
#
#                                                     url  ROE_IQR  PER_IQR  \
# 0     https://finance.naver.com/item/main.naver?code...    False    False
# 1     https://finance.naver.com/item/main.naver?code...    False    False
# 2     https://finance.naver.com/item/main.naver?code...    False     True
# 3     https://finance.naver.com/item/main.naver?code...    False    False
# 4     https://finance.naver.com/item/main.naver?code...    False    False
# ...                                                 ...      ...      ...
# 2427  https://finance.naver.com/item/main.naver?code...    False    False
# 2428  https://finance.naver.com/item/main.naver?code...    False     True
# 2429  https://finance.naver.com/item/main.naver?code...    False    False
# 2430  https://finance.naver.com/item/main.naver?code...    False    False
# 2431  https://finance.naver.com/item/main.naver?code...    False    False
#
#       PBR_IQR
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
# ...       ...
# 2427    False
# 2428    False
# 2429    False
# 2430    False
# 2431    False
#
# [2235 rows x 11 columns]

# %%
# 'AVG' 열에 대하여 이상치 여부를 판별해주는 함수
def is_AVG_outlier(df):
  avg_score = df['AVG']
  if avg_score > Q3['AVG'] + 1.5 * IQR['AVG'] or avg_score < Q1['AVG'] - 1.5 * IQR['AVG']:
      return True
  else:
      return False

df['AVG_IQR'] = df.apply(is_AVG_outlier, axis = 1) # axis = 1 지정 필수
df
# Out:
#           업종명  소속종목수      소속종목명    ROE     PER   PBR    AVG  \
# 0     우주항공과국방     16  한화에어로스페이스   7.33   12.51  0.89  31.28
# 1     우주항공과국방     16     LIG넥스원  17.50   13.47  2.18  31.28
# 2     우주항공과국방     16     한국항공우주   7.14   56.01  3.85  31.28
# 3     우주항공과국방     16      한화시스템   5.38   26.73  1.15  31.28
# 4     우주항공과국방     16        제노코  20.25   28.00  5.28  31.28
# ...       ...    ...        ...    ...     ...   ...    ...
# 2427    석유와가스     20    SK이노베이션   9.01   11.34  0.82   7.11
# 2428    석유와가스     20     중앙에너비스   0.90  235.47  1.53   7.11
# 2429    석유와가스     20      세원이앤씨  -4.96  -14.56  0.75   7.11
# 2430    석유와가스     20      S-Oil  28.09    5.53  1.40   7.11
# 2431    석유와가스     20     S-Oil우  28.09    5.53  1.40   7.11
#
#                                                     url  ROE_IQR  PER_IQR  \
# 0     https://finance.naver.com/item/main.naver?code...    False    False
# 1     https://finance.naver.com/item/main.naver?code...    False    False
# 2     https://finance.naver.com/item/main.naver?code...    False     True
# 3     https://finance.naver.com/item/main.naver?code...    False    False
# 4     https://finance.naver.com/item/main.naver?code...    False    False
# ...                                                 ...      ...      ...
# 2427  https://finance.naver.com/item/main.naver?code...    False    False
# 2428  https://finance.naver.com/item/main.naver?code...    False     True
# 2429  https://finance.naver.com/item/main.naver?code...    False    False
# 2430  https://finance.naver.com/item/main.naver?code...    False    False
# 2431  https://finance.naver.com/item/main.naver?code...    False    False
#
#       PBR_IQR  AVG_IQR
# 0       False    False
# 1       False    False
# 2       False    False
# 3       False    False
# 4        True    False
# ...       ...      ...
# 2427    False    False
# 2428    False    False
# 2429    False    False
# 2430    False    False
# 2431    False    False
#
# [2235 rows x 12 columns]

# %%
# ROE값이 이상치인 행은 제거하여 필터링
df = df.loc[df['ROE_IQR'] == False]
# 이상치여부를 나타내는 열 제거
del df['ROE_IQR']

df
# Out:
#           업종명  소속종목수      소속종목명    ROE     PER   PBR    AVG  \
# 0     우주항공과국방     16  한화에어로스페이스   7.33   12.51  0.89  31.28
# 1     우주항공과국방     16     LIG넥스원  17.50   13.47  2.18  31.28
# 2     우주항공과국방     16     한국항공우주   7.14   56.01  3.85  31.28
# 3     우주항공과국방     16      한화시스템   5.38   26.73  1.15  31.28
# 4     우주항공과국방     16        제노코  20.25   28.00  5.28  31.28
# ...       ...    ...        ...    ...     ...   ...    ...
# 2427    석유와가스     20    SK이노베이션   9.01   11.34  0.82   7.11
# 2428    석유와가스     20     중앙에너비스   0.90  235.47  1.53   7.11
# 2429    석유와가스     20      세원이앤씨  -4.96  -14.56  0.75   7.11
# 2430    석유와가스     20      S-Oil  28.09    5.53  1.40   7.11
# 2431    석유와가스     20     S-Oil우  28.09    5.53  1.40   7.11
#
#                                                     url  PER_IQR  PBR_IQR  \
# 0     https://finance.naver.com/item/main.naver?code...    False    False
# 1     https://finance.naver.com/item/main.naver?code...    False    False
# 2     https://finance.naver.com/item/main.naver?code...     True    False
# 3     https://finance.naver.com/item/main.naver?code...    False    False
# 4     https://finance.naver.com/item/main.naver?code...    False     True
# ...                                                 ...      ...      ...
# 2427  https://finance.naver.com/item/main.naver?code...    False    False
# 2428  https://finance.naver.com/item/main.naver?code...     True    False
# 2429  https://finance.naver.com/item/main.naver?code...    False    False
# 2430  https://finance.naver.com/item/main.naver?code...    False    False
# 2431  https://finance.naver.com/item/main.naver?code...    False    False
#
#       AVG_IQR
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# ...       ...
# 2427    False
# 2428    False
# 2429    False
# 2430    False
# 2431    False
#
# [1935 rows x 11 columns]

# %%
# PER 값이 이상치인 행은 제거하여 필터링
df = df.loc[df['PER_IQR'] == False]
# 이상치여부를 나타내는 열 제거
del df['PER_IQR']

df
# Out:
#           업종명  소속종목수      소속종목명    ROE    PER   PBR    AVG  \
# 0     우주항공과국방     16  한화에어로스페이스   7.33  12.51  0.89  31.28
# 1     우주항공과국방     16     LIG넥스원  17.50  13.47  2.18  31.28
# 3     우주항공과국방     16      한화시스템   5.38  26.73  1.15  31.28
# 4     우주항공과국방     16        제노코  20.25  28.00  5.28  31.28
# 5     우주항공과국방     16        휴니드   7.11  11.90  0.76  31.28
# ...       ...    ...        ...    ...    ...   ...    ...
# 2426    석유와가스     20    에스아이리소스  25.23  11.75  2.54   7.11
# 2427    석유와가스     20    SK이노베이션   9.01  11.34  0.82   7.11
# 2429    석유와가스     20      세원이앤씨  -4.96 -14.56  0.75   7.11
# 2430    석유와가스     20      S-Oil  28.09   5.53  1.40   7.11
# 2431    석유와가스     20     S-Oil우  28.09   5.53  1.40   7.11
#
#                                                     url  PBR_IQR  AVG_IQR
# 0     https://finance.naver.com/item/main.naver?code...    False    False
# 1     https://finance.naver.com/item/main.naver?code...    False    False
# 3     https://finance.naver.com/item/main.naver?code...    False    False
# 4     https://finance.naver.com/item/main.naver?code...     True    False
# 5     https://finance.naver.com/item/main.naver?code...    False    False
# ...                                                 ...      ...      ...
# 2426  https://finance.naver.com/item/main.naver?code...    False    False
# 2427  https://finance.naver.com/item/main.naver?code...    False    False
# 2429  https://finance.naver.com/item/main.naver?code...    False    False
# 2430  https://finance.naver.com/item/main.naver?code...    False    False
# 2431  https://finance.naver.com/item/main.naver?code...    False    False
#
# [1575 rows x 10 columns]

# %%
# PBR값이 이상치인 행은 제거하여 필터링
df = df.loc[df['PBR_IQR'] == False]
# 이상치여부를 나타내는 열 제거
del df['PBR_IQR']

df
# Out:
#           업종명  소속종목수      소속종목명    ROE    PER   PBR    AVG  \
# 0     우주항공과국방     16  한화에어로스페이스   7.33  12.51  0.89  31.28
# 1     우주항공과국방     16     LIG넥스원  17.50  13.47  2.18  31.28
# 3     우주항공과국방     16      한화시스템   5.38  26.73  1.15  31.28
# 5     우주항공과국방     16        휴니드   7.11  11.90  0.76  31.28
# 6     우주항공과국방     16         빅텍   9.68  29.37  2.73  31.28
# ...       ...    ...        ...    ...    ...   ...    ...
# 2426    석유와가스     20    에스아이리소스  25.23  11.75  2.54   7.11
# 2427    석유와가스     20    SK이노베이션   9.01  11.34  0.82   7.11
# 2429    석유와가스     20      세원이앤씨  -4.96 -14.56  0.75   7.11
# 2430    석유와가스     20      S-Oil  28.09   5.53  1.40   7.11
# 2431    석유와가스     20     S-Oil우  28.09   5.53  1.40   7.11
#
#                                                     url  AVG_IQR
# 0     https://finance.naver.com/item/main.naver?code...    False
# 1     https://finance.naver.com/item/main.naver?code...    False
# 3     https://finance.naver.com/item/main.naver?code...    False
# 5     https://finance.naver.com/item/main.naver?code...    False
# 6     https://finance.naver.com/item/main.naver?code...    False
# ...                                                 ...      ...
# 2426  https://finance.naver.com/item/main.naver?code...    False
# 2427  https://finance.naver.com/item/main.naver?code...    False
# 2429  https://finance.naver.com/item/main.naver?code...    False
# 2430  https://finance.naver.com/item/main.naver?code...    False
# 2431  https://finance.naver.com/item/main.naver?code...    False
#
# [1542 rows x 9 columns]

# %%
#AVG값이 이상치인 행은 제거하여 필터링
df = df.loc[df['AVG_IQR'] == False]
# 이상치여부를 나타내는 열 제거
del df['AVG_IQR']

df
# Out:
#           업종명  소속종목수      소속종목명    ROE    PER   PBR    AVG  \
# 0     우주항공과국방     16  한화에어로스페이스   7.33  12.51  0.89  31.28
# 1     우주항공과국방     16     LIG넥스원  17.50  13.47  2.18  31.28
# 3     우주항공과국방     16      한화시스템   5.38  26.73  1.15  31.28
# 5     우주항공과국방     16        휴니드   7.11  11.90  0.76  31.28
# 6     우주항공과국방     16         빅텍   9.68  29.37  2.73  31.28
# ...       ...    ...        ...    ...    ...   ...    ...
# 2426    석유와가스     20    에스아이리소스  25.23  11.75  2.54   7.11
# 2427    석유와가스     20    SK이노베이션   9.01  11.34  0.82   7.11
# 2429    석유와가스     20      세원이앤씨  -4.96 -14.56  0.75   7.11
# 2430    석유와가스     20      S-Oil  28.09   5.53  1.40   7.11
# 2431    석유와가스     20     S-Oil우  28.09   5.53  1.40   7.11
#
#                                                     url
# 0     https://finance.naver.com/item/main.naver?code...
# 1     https://finance.naver.com/item/main.naver?code...
# 3     https://finance.naver.com/item/main.naver?code...
# 5     https://finance.naver.com/item/main.naver?code...
# 6     https://finance.naver.com/item/main.naver?code...
# ...                                                 ...
# 2426  https://finance.naver.com/item/main.naver?code...
# 2427  https://finance.naver.com/item/main.naver?code...
# 2429  https://finance.naver.com/item/main.naver?code...
# 2430  https://finance.naver.com/item/main.naver?code...
# 2431  https://finance.naver.com/item/main.naver?code...
#
# [1416 rows x 8 columns]

# %% [markdown]
# #이상치 존재 유무 시각화
#
# ```

# %%
#결측치/이상치를 모두 제거 한 후 시각화
plt.figure(figsize=(12,8))
sns.boxplot(data=df[['ROE','PER','PBR','AVG']],color='red',notch=True)
plt.show()

# %%
df.describe()
# Out:
#              소속종목수          ROE          PER          PBR          AVG
# count  1416.000000  1416.000000  1416.000000  1416.000000  1416.000000
# mean     67.356638     7.982881     9.123058     1.130833    14.931871
# std      40.736323    10.871249    13.947535     0.794498     9.618971
# min       5.000000   -23.660000   -33.290000     0.090000     0.320000
# 25%      28.000000     3.897500     3.680000     0.530000     7.770000
# 50%      69.000000     8.580000     9.265000     0.900000    14.140000
# 75%      92.000000    14.252500    16.360000     1.492500    17.700000
# max     158.000000    34.650000    48.920000     4.210000    51.840000

# %% [markdown]
# **데이터프레임** 순서 정렬하기

# %%
#데이터 값 분포 시각화
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(15,10))

for i, col in enumerate(df):
    if 3 <= i <= 6:
        ax = fig.add_subplot(3, 2, i)
        ax.title.set_text(col)

        if col == "PER":
            df[col].plot.hist(bins=[-38,-30,-25,-20,-15,-10,-5,0,5,10,15,20,25,30,35,40,45,52],color='r',edgecolor = 'whitesmoke',linewidth = 1.4)
        elif col == "PBR":
            df[col].plot.hist(bins=[0.05,0.075,0.1,0.2,0.35,0.5,0.6,0.75,0.9,1,1.25,1.5,1.7,1.9,2.0,2.25,2.5,2.75,3,3.5,3.75,4,4.25,4.5],color='b',edgecolor = 'whitesmoke',linewidth = 1.4)
        elif col == "ROE":
            df[col].plot.hist(bins=[-25,-23,-20,-18,-15,-13,-10,-9,-5,0,1,2,3,5,7,8,9,10,13,15,17,20,22,25,27,30,33,35],color='g',edgecolor = 'whitesmoke',linewidth = 1.4)
        elif col == "AVG":
            df[col].plot.hist(bins=[0,3,5,8,9,10,12,13,14,15,17,18,19,20,25,27,30,31,33,39,40,43,52],color='y',edgecolor = 'whitesmoke',linewidth = 1.4)

plt.show()

# %%
#PER 낮을수록 좋음
# per 오름차순 (NaN 제외/ 마이너스부호포함(음수포함))
per_ascending = df.sort_values(by="PER", ascending=True)
per_ascending[(per_ascending["PER"] != None)].head(20)
# Out:
#              업종명  소속종목수    소속종목명    ROE    PER   PBR    AVG  \
# 1303          조선     25   STX중공업  -2.23 -33.29  0.78   5.61
# 1953        창업투자     80     큐캐피탈  -2.30 -32.88  0.73   3.79
# 631        자동차부품    141       삼기  -2.99 -32.74  0.90  14.14
# 751        자동차부품    141    센트랄모텍  -4.42 -32.50  1.54  14.14
# 497           건설     73     이화공영  -8.83 -31.84  2.69   6.54
# 235    방송과엔터테인먼트     56   에프엔씨엔터  -4.98 -31.58  1.52  37.89
# 1724          철강     53     동양철관  -4.63 -31.32  1.49   3.02
# 688        자동차부품    141     대원강업  -1.36 -31.19  0.43  14.14
# 2265       IT서비스     76      씨이랩 -10.94 -30.32  3.43  19.04
# 1686       소프트웨어     59    한컴MDS  -4.00 -30.10  1.15  32.07
# 456           건설     73     특수건설  -5.03 -29.83  1.46   6.54
# 2192  양방향미디어와서비스     11   티사이언티픽  -2.75 -29.69  0.60  19.76
# 556          핸드셋     69      와이팜  -7.43 -29.55  2.39  26.10
# 1323          식품     89  마니커에프앤지  -3.89 -29.49  1.02  11.93
# 827      전자장비와기기     92     옵트론텍  -4.34 -28.97  1.19  16.22
# 1782    컴퓨터와주변기기     24     주연테크  -3.97 -28.87  1.14  42.19
# 444           건설     73    그린플러스  -9.82 -28.65  2.41   6.54
# 2227       IT서비스     76     시티랩스  -4.69 -28.62  1.28  19.04
# 407     가정용기기와용품     24   엔바이오니아 -13.47 -28.01  4.02   9.77
# 1656       소프트웨어     59     라온피플 -10.41 -27.47  2.96  32.07
#
#                                                     url
# 1303  https://finance.naver.com/item/main.naver?code...
# 1953  https://finance.naver.com/item/main.naver?code...
# 631   https://finance.naver.com/item/main.naver?code...
# 751   https://finance.naver.com/item/main.naver?code...
# 497   https://finance.naver.com/item/main.naver?code...
# 235   https://finance.naver.com/item/main.naver?code...
# 1724  https://finance.naver.com/item/main.naver?code...
# 688   https://finance.naver.com/item/main.naver?code...
# 2265  https://finance.naver.com/item/main.naver?code...
# 1686  https://finance.naver.com/item/main.naver?code...
# 456   https://finance.naver.com/item/main.naver?code...
# 2192  https://finance.naver.com/item/main.naver?code...
# 556   https://finance.naver.com/item/main.naver?code...
# 1323  https://finance.naver.com/item/main.naver?code...
# 827   https://finance.naver.com/item/main.naver?code...
# 1782  https://finance.naver.com/item/main.naver?code...
# 444   https://finance.naver.com/item/main.naver?code...
# 2227  https://finance.naver.com/item/main.naver?code...
# 407   https://finance.naver.com/item/main.naver?code...
# 1656  https://finance.naver.com/item/main.naver?code...

# %%
#PBR 낮을수록좋음
# pbr 오름차순 (NaN 제외)
pbr_ascending = df.sort_values(by="PBR", ascending=True)
pbr_ascending.head(20)
#pbr_ascending[(pbr_ascending["PBR"] != None)].head(20)
# Out:
#                업종명  소속종목수      소속종목명    ROE    PER   PBR    AVG  \
# 397       레저용장비와제품     10       헝셩그룹   0.78  12.00  0.09   3.86
# 130            화장품     54   오가닉티코스메틱  -4.48  -2.10  0.11  30.97
# 1581            화학    114        GRT   5.46   2.53  0.13   9.26
# 482             건설     73        HDC   0.93  18.44  0.15   6.54
# 1571            화학    114       대한화섬   4.02   5.06  0.16   9.26
# 995           생명보험      7       한화생명   8.79   2.07  0.17   6.73
# 1092  섬유,의류,신발,호화품     80  이스트아시아홀딩스   1.03  15.07  0.18   5.17
# 674          자동차부품    141       세원정공   1.90   9.48  0.18  14.14
# 711          자동차부품    141         넥센   0.70  26.50  0.18  14.14
# 2413         석유와가스     20     경동인베스트   4.33   4.53  0.18   7.11
# 668          자동차부품    141        넥센우   0.70  26.50  0.18  14.14
# 2338        가스유틸리티     12         E1  11.73   2.01  0.19   5.01
# 1726            철강     53      세아홀딩스   4.07   4.88  0.19   3.02
# 1587            화학    114       태광산업   7.52   3.61  0.19   9.26
# 1718            철강     53   KISCO홀딩스  13.63   2.05  0.19   3.02
# 460             건설     73       한신공영   7.24   2.94  0.20   6.54
# 1535            화학    114    크리스탈신소재   2.58   7.90  0.20   9.26
# 675          자동차부품    141       세원물산  12.08   1.93  0.22  14.14
# 2209            은행     11    BNK금융지주   9.63   2.48  0.23   4.30
# 133            화장품     54       컬러레이  10.90   2.35  0.23  30.97
#
#                                                     url
# 397   https://finance.naver.com/item/main.naver?code...
# 130   https://finance.naver.com/item/main.naver?code...
# 1581  https://finance.naver.com/item/main.naver?code...
# 482   https://finance.naver.com/item/main.naver?code...
# 1571  https://finance.naver.com/item/main.naver?code...
# 995   https://finance.naver.com/item/main.naver?code...
# 1092  https://finance.naver.com/item/main.naver?code...
# 674   https://finance.naver.com/item/main.naver?code...
# 711   https://finance.naver.com/item/main.naver?code...
# 2413  https://finance.naver.com/item/main.naver?code...
# 668   https://finance.naver.com/item/main.naver?code...
# 2338  https://finance.naver.com/item/main.naver?code...
# 1726  https://finance.naver.com/item/main.naver?code...
# 1587  https://finance.naver.com/item/main.naver?code...
# 1718  https://finance.naver.com/item/main.naver?code...
# 460   https://finance.naver.com/item/main.naver?code...
# 1535  https://finance.naver.com/item/main.naver?code...
# 675   https://finance.naver.com/item/main.naver?code...
# 2209  https://finance.naver.com/item/main.naver?code...
# 133   https://finance.naver.com/item/main.naver?code...

# %%
#ROE 높을수록좋음.
# ROE 내림차순 (NaN 제외)
roe_ascending = df.sort_values(by="ROE", ascending=False)
roe_ascending.head(20)
#roe_ascending[(roe_ascending["ROE"] != None) & (roe_ascending["ROE"]>0)].head(20)
# Out:
#                업종명  소속종목수      소속종목명    ROE    PER   PBR    AVG  \
# 1874    디스플레이장비및부품     86    이녹스첨단소재  34.65   7.18  2.07  17.70
# 1719            철강     53       한국특강  34.60   3.09  0.89   3.02
# 2371      게임엔터테인먼트     34     카카오게임즈  34.51   7.24  1.96  17.72
# 60              기계     93      우진플라임  34.14   2.88  0.85  17.37
# 750          자동차부품    141       디아이씨  33.38   6.83  1.68  14.14
# 626          자동차부품    141        디젠스  33.31   7.37  2.11  14.14
# 2251         IT서비스     76        유엔젤  33.27   3.03  0.77  19.04
# 760        전자장비와기기     92       비에이치  33.19   7.65  1.99  16.22
# 395       레저용장비와제품     10        이녹스  33.15   3.66  0.99   3.86
# 2158            광고     13        이엠넷  32.98   4.91  1.39  14.36
# 2373      게임엔터테인먼트     34     데브시스터즈  32.96  11.38  2.97  17.72
# 1537            화학    114       이수화학  32.82   4.48  1.42   9.26
# 1032  섬유,의류,신발,호화품     80  제이에스코퍼레이션  32.55   3.80  1.00   5.17
# 2359      게임엔터테인먼트     34        엠게임  32.54   7.19  1.94  17.72
# 1053  섬유,의류,신발,호화품     80    더네이쳐홀딩스  32.08   6.83  1.90   5.17
# 1807    디스플레이장비및부품     86      AP시스템  31.96   4.81  1.32  17.70
# 1733            철강     53       동국제강  31.86   1.52  0.40   3.02
# 2415         석유와가스     20      한국쉘석유  31.71  10.90  3.37   7.11
# 2028     반도체와반도체장비    134    하나머티리얼즈  31.61  11.59  3.16   8.47
# 1506     건강관리장비와용품     68    루트로닉3우C  31.48  13.42  3.68  14.64
#
#                                                     url
# 1874  https://finance.naver.com/item/main.naver?code...
# 1719  https://finance.naver.com/item/main.naver?code...
# 2371  https://finance.naver.com/item/main.naver?code...
# 60    https://finance.naver.com/item/main.naver?code...
# 750   https://finance.naver.com/item/main.naver?code...
# 626   https://finance.naver.com/item/main.naver?code...
# 2251  https://finance.naver.com/item/main.naver?code...
# 760   https://finance.naver.com/item/main.naver?code...
# 395   https://finance.naver.com/item/main.naver?code...
# 2158  https://finance.naver.com/item/main.naver?code...
# 2373  https://finance.naver.com/item/main.naver?code...
# 1537  https://finance.naver.com/item/main.naver?code...
# 1032  https://finance.naver.com/item/main.naver?code...
# 2359  https://finance.naver.com/item/main.naver?code...
# 1053  https://finance.naver.com/item/main.naver?code...
# 1807  https://finance.naver.com/item/main.naver?code...
# 1733  https://finance.naver.com/item/main.naver?code...
# 2415  https://finance.naver.com/item/main.naver?code...
# 2028  https://finance.naver.com/item/main.naver?code...
# 1506  https://finance.naver.com/item/main.naver?code...

# %%
df[(df['ROE'] >df['ROE'].mean()) & (df['PBR'] <df['PBR'].mean()) & (df['PER']<df['PER'].mean())]
# Out:
#         업종명  소속종목수      소속종목명    ROE   PER   PBR    AVG  \
# 33       기계     93  현대두산인프라코어  20.04  2.31  0.73  17.37
# 39       기계     93       대창단조  12.81  5.69  0.59  17.37
# 60       기계     93      우진플라임  34.14  2.88  0.85  17.37
# 61       기계     93        코메론   9.60  5.08  0.45  17.37
# 68       기계     93         흥국  11.87  8.64  0.91  17.37
# ...     ...    ...        ...    ...   ...   ...    ...
# 2417  석유와가스     20       미창석유  11.75  4.09  0.40   7.11
# 2418  석유와가스     20        GS우  15.69  2.48  0.35   7.11
# 2419  석유와가스     20   SK디스커버리우  11.96  2.56  0.28   7.11
# 2420  석유와가스     20    SK디스커버리  11.96  2.56  0.28   7.11
# 2423  석유와가스     20         GS  15.69  2.48  0.35   7.11
#
#                                                     url
# 33    https://finance.naver.com/item/main.naver?code...
# 39    https://finance.naver.com/item/main.naver?code...
# 60    https://finance.naver.com/item/main.naver?code...
# 61    https://finance.naver.com/item/main.naver?code...
# 68    https://finance.naver.com/item/main.naver?code...
# ...                                                 ...
# 2417  https://finance.naver.com/item/main.naver?code...
# 2418  https://finance.naver.com/item/main.naver?code...
# 2419  https://finance.naver.com/item/main.naver?code...
# 2420  https://finance.naver.com/item/main.naver?code...
# 2423  https://finance.naver.com/item/main.naver?code...
#
# [346 rows x 8 columns]

# %%
df_s = df.sort_values(by=['ROE', 'PER','PBR'], ascending=[False, True,True]) 
df_s.head()
# Out:
#              업종명  소속종목수    소속종목명    ROE   PER   PBR    AVG  \
# 1874  디스플레이장비및부품     86  이녹스첨단소재  34.65  7.18  2.07  17.70
# 1719          철강     53     한국특강  34.60  3.09  0.89   3.02
# 2371    게임엔터테인먼트     34   카카오게임즈  34.51  7.24  1.96  17.72
# 60            기계     93    우진플라임  34.14  2.88  0.85  17.37
# 750        자동차부품    141     디아이씨  33.38  6.83  1.68  14.14
#
#                                                     url
# 1874  https://finance.naver.com/item/main.naver?code...
# 1719  https://finance.naver.com/item/main.naver?code...
# 2371  https://finance.naver.com/item/main.naver?code...
# 60    https://finance.naver.com/item/main.naver?code...
# 750   https://finance.naver.com/item/main.naver?code...

# %%
#PER은 현재주식가격을 주당순이익으로 나눈값
#PER 시장평균
#PER 주가수익비율  = 주가 /주당순이익
#PER은 같은산업군에서 비교해야함.   *
#PBR : 주가순자산비율 (주가/주당순자산(총자산-총부채/발행주식수))
#PBR<1 저평가   *
#ROE 10%정도 이상을 많이 추천하는데, ROE 10%이상만되어도 우수한기업 20-30%일경우 굉장한성장  *
#ROE가높을수록 PBR도 높아진다
#PER이 낮을수록 기업의 수익성이좋고, PBR이 낮을수록 기업의 재무건전성이 좋다고 생각된다.
#통상적으로 PER은 10보다 낮을 때, PBR은 1모다 낮을때 저평가되어있다고 말한다. 하지만 기업의 수익성이나 자산은 업종별로 천차만별이기 때문에
#업종평균 PER과 PBR로 고려해야한다.
#http://data.krx.co.kr/contents/MDC/MDI/mdiLoader/index.cmd?menuId=MDC0201010107
